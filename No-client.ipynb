# %% [markdown]
# ## No client example

# %%
import glob
import xarray as xr

# %%
mic_filepath = '../micasa-data/'

# %%
# Test some random paths
path_test_mon = glob.glob(mic_filepath + 
                          'daily-0.1deg-final/holding/daily/2016/01/MiCASA_v1_flux_x3600_y1800_daily_201601*')
path_sorted_mon = sorted(path_test_mon)

# %%
path_test_yr = glob.glob(mic_filepath + 'daily-0.1deg-final/holding/daily/2016/??/MiCASA_v1_flux_x3600_y1800_daily_20??????.nc4')
path_sorted_yr = sorted(path_test_yr)

# %%
# %%time
ds = xr.open_mfdataset(path_sorted_mon, combine='nested', concat_dim='time', parallel=True)
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /usr/local/other/GEOSpyD/24.4.0-0_py3.12/2024-05-31/share/proj failed
# CPU times: user 2.59 s, sys: 396 ms, total: 2.98 s
# Wall time: 7.72 s

# %%
ds
# Out:
# <xarray.Dataset> Size: 5GB
# Dimensions:    (lat: 1800, lon: 3600, time: 31, nv: 2)
# Coordinates:
#   * lat        (lat) float64 14kB -89.95 -89.85 -89.75 ... 89.75 89.85 89.95
#   * lon        (lon) float64 29kB -179.9 -179.8 -179.8 ... 179.8 179.8 179.9
#   * time       (time) datetime64[ns] 248B 2016-01-01 2016-01-02 ... 2016-01-31
# Dimensions without coordinates: nv
# Data variables:
#     time_bnds  (time, nv) datetime64[ns] 496B dask.array<chunksize=(1, 2), meta=np.ndarray>
#     NPP        (time, lat, lon) float32 804MB dask.array<chunksize=(1, 600, 1200), meta=np.ndarray>
#     Rh         (time, lat, lon) float32 804MB dask.array<chunksize=(1, 600, 1200), meta=np.ndarray>
#     FIRE       (time, lat, lon) float32 804MB dask.array<chunksize=(1, 600, 1200), meta=np.ndarray>
#     FUEL       (time, lat, lon) float32 804MB dask.array<chunksize=(1, 600, 1200), meta=np.ndarray>
#     ATMC       (time, lat, lon) float32 804MB dask.array<chunksize=(1, 600, 1200), meta=np.ndarray>
# ...

# %%
# %%time
ds = xr.open_mfdataset(path_sorted_yr, combine='nested', concat_dim='time', parallel=True)
# Out:
# CPU times: user 5.89 s, sys: 848 ms, total: 6.74 s
# Wall time: 31 s

# %%
ds
# Out:
# <xarray.Dataset> Size: 57GB
# Dimensions:    (lat: 1800, lon: 3600, time: 366, nv: 2)
# Coordinates:
#   * lat        (lat) float64 14kB -89.95 -89.85 -89.75 ... 89.75 89.85 89.95
#   * lon        (lon) float64 29kB -179.9 -179.8 -179.8 ... 179.8 179.8 179.9
#   * time       (time) datetime64[ns] 3kB 2016-01-01 2016-01-02 ... 2016-12-31
# Dimensions without coordinates: nv
# Data variables:
#     time_bnds  (time, nv) datetime64[ns] 6kB dask.array<chunksize=(1, 2), meta=np.ndarray>
#     NPP        (time, lat, lon) float32 9GB dask.array<chunksize=(1, 600, 1200), meta=np.ndarray>
#     Rh         (time, lat, lon) float32 9GB dask.array<chunksize=(1, 600, 1200), meta=np.ndarray>
#     FIRE       (time, lat, lon) float32 9GB dask.array<chunksize=(1, 600, 1200), meta=np.ndarray>
#     FUEL       (time, lat, lon) float32 9GB dask.array<chunksize=(1, 600, 1200), meta=np.ndarray>
#     ATMC       (time, lat, lon) float32 9GB dask.array<chunksize=(1, 600, 1200), meta=np.ndarray>
# ...
